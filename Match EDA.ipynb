# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('NCAA_Tourney_2002_2018.csv')

# %%
df.head()
# Out:
#    team1_id  team1_score  team2_id  team2_score WLoc  num_ot team1_position  \
# 0      1104           86      1194           78    N       0            Y02
# 1      1112           86      1364           81    N       0            Z03
# 2      1181           84      1457           37    N       0            Y01
# 3      1231           75      1428           56    N       0            Y05
# 4      1242           70      1221           59    N       0            X01
#
#   team2_position  team1_seed  team2_seed       ...        team1_adjoe  \
# 0            Y15           2          15       ...           111.4954
# 1            Z14           3          14       ...           117.3877
# 2            Y16           1          16       ...           118.5999
# 3            Y12           5          12       ...           109.6136
# 4            X16           1          16       ...           115.0406
#
#    team1_de team1_adjde team2_tempo team2_adjtempo  team2_oe team2_adjoe  \
# ...

# %%
df.shape
# Out:
# (1111, 104)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Columns: 104 entries, team1_id to game_id
# dtypes: float64(74), int64(18), object(12)
# memory usage: 902.8+ KB

# %%
df.describe()
# Out:
#           team1_id  team1_score     team2_id  team2_score       num_ot  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000
# mean   1294.204320    75.403240  1294.951395    63.988299     0.071107
# std     101.639216    10.719493   106.298777    10.414510     0.302218
# min    1104.000000    47.000000  1102.000000    29.000000     0.000000
# 25%    1211.000000    68.000000  1209.500000    57.000000     0.000000
# 50%    1277.000000    75.000000  1295.000000    64.000000     0.000000
# 75%    1393.000000    82.000000  1393.000000    71.000000     0.000000
# max    1463.000000   121.000000  1463.000000   105.000000     2.000000
#
#         team1_seed   team2_seed   strongseed     weakseed       season  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000
# mean      5.141314     8.807381     3.909991    10.038704  2010.104410
# std       3.981354     4.623167     3.094459     3.946870     4.899705
# ...

# %%
list(df.columns)
# Out:
# ['team1_id',
#  'team1_score',
#  'team2_id',
#  'team2_score',
#  'WLoc',
#  'num_ot',
#  'team1_position',
#  'team2_position',
#  'team1_seed',
#  'team2_seed',
#  'strongseed',
#  'weakseed',
#  'team1_region',
#  'team2_region',
#  'slot',
#  'team1_teamname',
#  'team2_teamname',
#  'season',
#  'host',
#  'host_lat',
#  'host_long',
#  'team1_lat',
#  'team1_long',
#  'team2_lat',
#  'team2_long',
#  'team1_coach_id',
#  'team1_pt_school_ncaa',
#  'team1_pt_overall_ncaa',
#  'team1_pt_school_s16',
#  'team1_pt_overall_s16',
#  'team1_pt_school_ff',
#  'team1_pt_overall_ff',
#  'team1_pt_career_school_wins',
#  'team1_pt_career_school_losses',
#  'team1_pt_career_overall_wins',
#  'team1_pt_career_overall_losses',
#  'team1_pt_team_season_wins',
#  'team1_pt_team_season_losses',
#  'team1_pt_coach_season_wins',
#  'team1_pt_coach_season_losses',
#  'team2_coach_id',
#  'team2_pt_school_ncaa',
#  'team2_pt_overall_ncaa',
#  'team2_pt_school_s16',
#  'team2_pt_overall_s16',
# ...

# %%
df.info(105)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 104 columns):
# team1_id                          int64
# team1_score                       int64
# team2_id                          int64
# team2_score                       int64
# WLoc                              object
# num_ot                            int64
# team1_position                    object
# team2_position                    object
# team1_seed                        int64
# team2_seed                        int64
# strongseed                        int64
# weakseed                          int64
# team1_region                      object
# team2_region                      object
# slot                              object
# team1_teamname                    object
# team2_teamname                    object
# season                            int64
# host                              object
# host_lat                          float64
# ...

# %%
#Ratio for each feature
missing = df.count()/df.shape[0]
#Sorting accending 
missing.sort_values()
#So we get the 8 missing features
# Out:
# team2_coaches_preseason           0.291629
# team2_ap_preseason                0.307831
# team2_coaches_before_final        0.344734
# team2_ap_final                    0.362736
# team1_coaches_preseason           0.551755
# team1_ap_preseason                0.585959
# team1_ap_final                    0.683168
# team1_coaches_before_final        0.687669
# team1_id                          1.000000
# team1_stlrate                     1.000000
# team1_opparate                    1.000000
# team1_arate                       1.000000
# team1_oppf3grate                  1.000000
# team1_f3grate                     1.000000
# team1_oppblockpct                 1.000000
# team1_oppftpct                    1.000000
# team1_ftpct                       1.000000
# team1_oppfg2pct                   1.000000
# team1_blockpct                    1.000000
# team1_oppstlrate                  1.000000
# team1_fg3pct                      1.000000
# team1_fg2pct                      1.000000
# ...

# %%
df_feature_catg = df.select_dtypes(include= [object])
feature_catg = df_feature_catg.columns #type: object feature
d_catg = df_feature_catg.shape[1]
print(d_catg)
# Out:
# 12

# %%
df[feature_catg].head() # catogorical data
# Out:
#   WLoc team1_position team2_position team1_region team2_region  slot  \
# 0    N            Y02            Y15            Y            Y  R1Y2
# 1    N            Z03            Z14            Z            Z  R1Z3
# 2    N            Y01            Y16            Y            Y  R1Y1
# 3    N            Y05            Y12            Y            Y  R1Y5
# 4    N            X01            X16            X            X  R1X1
#
#   team1_teamname team2_teamname         host    team1_coach_id  \
# 0        Alabama    FL Atlantic   greenville  fran-mccaffery-1
# 1        Arizona  Santa Barbara  albuquerque  fran-mccaffery-1
# 2           Duke       Winthrop   greenville  fran-mccaffery-1
# 3        Indiana           Utah   sacramento  mark-gottfried-1
# 4         Kansas     Holy Cross     st_louis  mark-gottfried-1
#
#      team2_coach_id         game_id
# 0    sidney-green-1  2002-1104-1194
# 1    bob-williams-1  2002-1112-1364
# 2    bob-williams-1  2002-1181-1457
# ...

# %%
numeric = list(df.describe().columns)
df[numeric].head() # Numeric data
# Out:
#    team1_id  team1_score  team2_id  team2_score  num_ot  team1_seed  \
# 0      1104           86      1194           78       0           2
# 1      1112           86      1364           81       0           3
# 2      1181           84      1457           37       0           1
# 3      1231           75      1428           56       0           5
# 4      1242           70      1221           59       0           1
#
#    team2_seed  strongseed  weakseed  season     ...       team1_oe  \
# 0          15           2        15    2002     ...       108.4361
# 1          14           3        14    2002     ...       111.0077
# 2          16           1        16    2002     ...       116.3726
# 3          12           5        12    2002     ...       105.3974
# 4          16           1        16    2002     ...       114.5438
#
#    team1_adjoe  team1_de  team1_adjde  team2_tempo  team2_adjtempo  team2_oe  \
# ...

# %%
df['team_diff'] = df['team1_id'] - df['team2_id']
df.team_diff[df.team_diff > 0 ] = 1
df.team_diff[df.team_diff <= 0 ] = 0
# Out:
# /Users/marcowang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/marcowang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30),dpi=300)
sns.heatmap(df.corr())
